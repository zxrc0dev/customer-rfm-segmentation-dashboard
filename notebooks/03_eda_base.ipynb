# %% [markdown]
# # Exploratory Data Analysis of Base Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parents[0]))

# Local src

from src.df_info import df_info

print('Done')
# Out:
# Done

# %%
path_csv_base = '../data/02_processed/cleaned_retail.csv'
path_csv_rfm = '../data/02_processed/rfm_retail.csv'
df_base = pd.read_csv(path_csv_base)
df_rfm = pd.read_csv(path_csv_rfm)

# %%
df_base['invoice_date'] = pd.to_datetime(df_base['invoice_date'])
df_base['invoice_date'].isnull().sum()

# %%
df_info(df_base)
# Out:
# ============================== Head ==============================
#   invoice stock_code                          description  quantity  \
# 0  489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434     79323P                   PINK CHERRY LIGHTS        12
# 2  489434     79323W                  WHITE CHERRY LIGHTS        12
# 3  489434      22041          RECORD FRAME 7" SINGLE SIZE        48
# 4  489434      21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#          invoice_date  price  customer_id         country  revenue  year  \
# 0 2009-12-01 07:45:00   6.95        13085  United Kingdom     83.4  2009
# 1 2009-12-01 07:45:00   6.75        13085  United Kingdom     81.0  2009
# 2 2009-12-01 07:45:00   6.75        13085  United Kingdom     81.0  2009
# 3 2009-12-01 07:45:00   2.10        13085  United Kingdom    100.8  2009
# 4 2009-12-01 07:45:00   1.25        13085  United Kingdom     30.0  2009
#
#    month
# 0     12
# 1     12
# 2     12
# 3     12
# 4     12
# ============================== Tail ==============================
#        invoice stock_code                      description  quantity  \
# 793750  581587      22613      PACK OF 20 SPACEBOY NAPKINS        12
# 793751  581587      22899      CHILDREN'S APRON DOLLY GIRL         6
# 793752  581587      23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 793753  581587      23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 793754  581587      22138     BAKING SET 9 PIECE RETROSPOT         3
#
#               invoice_date  price  customer_id country  revenue  year  month
# 793750 2011-12-09 12:50:00   0.85        12680  France    10.20  2011     12
# 793751 2011-12-09 12:50:00   2.10        12680  France    12.60  2011     12
# 793752 2011-12-09 12:50:00   4.15        12680  France    16.60  2011     12
# 793753 2011-12-09 12:50:00   4.15        12680  France    16.60  2011     12
# 793754 2011-12-09 12:50:00   4.95        12680  France    14.85  2011     12
# ============================== Shape ==============================
# (793755, 11)
# ============================== Info ==============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793755 entries, 0 to 793754
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice       793755 non-null  object
#  1   stock_code    793755 non-null  object
#  2   description   793755 non-null  object
#  3   quantity      793755 non-null  int64
#  4   invoice_date  793755 non-null  datetime64[ns]
#  5   price         793755 non-null  float64
#  6   customer_id   793755 non-null  int64
#  7   country       793755 non-null  object
#  8   revenue       793755 non-null  float64
#  9   year          793755 non-null  int32
#  10  month         793755 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(2), object(4)
# memory usage: 60.6+ MB
# None
# ============================== Columns ==============================
# Index(['invoice', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'price', 'customer_id', 'country', 'revenue', 'year', 'month'],
#       dtype='object')
# ============================== Describe ==============================
#             quantity                   invoice_date          price  \
# count  793755.000000                         793755  793755.000000
# mean       12.643784  2011-01-02 13:53:24.778502144       2.969689
# min    -74215.000000            2009-12-01 07:45:00       0.001000
# 25%         2.000000            2010-07-02 11:44:00       1.250000
# 50%         5.000000            2010-12-02 12:22:00       1.950000
# 75%        12.000000            2011-07-31 15:46:00       3.750000
# max     74215.000000            2011-12-09 12:50:00     649.500000
# std       142.083231                            NaN       4.474045
#
#          customer_id        revenue           year          month
# count  793755.000000  793755.000000  793755.000000  793755.000000
# mean    15319.991521      20.609825    2010.431165       7.411546
# min     12346.000000  -77183.600000    2009.000000       1.000000
# 25%     13971.000000       4.350000    2010.000000       5.000000
# 50%     15245.000000      11.700000    2010.000000       8.000000
# 75%     16791.000000      19.500000    2011.000000      10.000000
# max     18287.000000   77183.600000    2011.000000      12.000000
# std      1693.625884     148.643057       0.568658       3.424064
# ============================== NaN ==============================
# invoice         0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# price           0
# customer_id     0
# country         0
# revenue         0
# year            0
# month           0
# dtype: int64
# ============================== Duplicates ==============================
# 0
# ============================== Cardinality & Top Values ==============================
# invoice 43848 invoice
# 576339    0.000682
# 579196    0.000670
# 580727    0.000664
# 578270    0.000556
# 573576    0.000547
# Name: proportion, dtype: float64
# stock_code 4628 stock_code
# 85123A    0.006493
# 22423     0.004631
# 85099B    0.004258
# 84879     0.003412
# 20725     0.003384
# Name: proportion, dtype: float64
# description 5237 description
# WHITE HANGING HEART T-LIGHT HOLDER    0.006484
# REGENCY CAKESTAND 3 TIER              0.004631
# JUMBO BAG RED RETROSPOT               0.003418
# ASSORTED COLOUR BIRD ORNAMENT         0.003412
# PARTY BUNTING                         0.002671
# Name: proportion, dtype: float64
# country 41 country
# United Kingdom    0.899853
# Germany           0.020983
# EIRE              0.019858
# France            0.016875
# Netherlands       0.006319
# Name: proportion, dtype: float64

# %% [markdown]
# - the records for year 2009 are only since start of Dec, so only 1 month recorded;

# %%
df_base['year'] = df_base['invoice_date'].dt.year
df_base['month'] = df_base['invoice_date'].dt.month
print(df_base.columns)
df_base
# Out:
# Index(['invoice', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'price', 'customer_id', 'country', 'revenue', 'year', 'month'],
#       dtype='object')
#        invoice stock_code                          description  quantity  \
# 0       489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434     79323P                   PINK CHERRY LIGHTS        12
# 2       489434     79323W                  WHITE CHERRY LIGHTS        12
# 3       489434      22041          RECORD FRAME 7" SINGLE SIZE        48
# 4       489434      21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...        ...                                  ...       ...
# 793750  581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 793751  581587      22899          CHILDREN'S APRON DOLLY GIRL         6
# 793752  581587      23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 793753  581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 793754  581587      22138         BAKING SET 9 PIECE RETROSPOT         3
#
#               invoice_date  price  customer_id         country  revenue  year  \
# 0      2009-12-01 07:45:00   6.95        13085  United Kingdom    83.40  2009
# 1      2009-12-01 07:45:00   6.75        13085  United Kingdom    81.00  2009
# 2      2009-12-01 07:45:00   6.75        13085  United Kingdom    81.00  2009
# 3      2009-12-01 07:45:00   2.10        13085  United Kingdom   100.80  2009
# 4      2009-12-01 07:45:00   1.25        13085  United Kingdom    30.00  2009
# ...                    ...    ...          ...             ...      ...   ...
# 793750 2011-12-09 12:50:00   0.85        12680          France    10.20  2011
# 793751 2011-12-09 12:50:00   2.10        12680          France    12.60  2011
# 793752 2011-12-09 12:50:00   4.15        12680          France    16.60  2011
# 793753 2011-12-09 12:50:00   4.15        12680          France    16.60  2011
# 793754 2011-12-09 12:50:00   4.95        12680          France    14.85  2011
#
#         month
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
# ...       ...
# 793750     12
# 793751     12
# 793752     12
# 793753     12
# 793754     12
#
# [793755 rows x 11 columns]

# %%
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='year', y='revenue', data=df_base)

ax.set_yscale("log") 

plt.title('Revenue Distribution by Year (Log Scale)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='year', y='quantity', data=df_base)

ax.set_yscale("log") 

plt.title('Revenue Distribution by Quantity (Log Scale)')
plt.show()

# %% [markdown]
# - see the consistency in order sizes across years (50% of all is 2-12 units per order);
# - 2010 has spike of high volume order compared to 2009 (1 month) and 2011;

# %%
year_rev = df_base.groupby('year')['revenue'].sum().reset_index()
year_rev.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# - the total revenue are roughly the same for 2010 (1) and 2011 (2);

# %%
year_month_rev = df_base.groupby(['year','month'])['revenue'].sum().reset_index()
year_month_rev['year_month'] = year_month_rev['year'].astype(str) + '-' + year_month_rev['month'].astype(str).str.zfill(2)
year_month_rev = year_month_rev.sort_values('year_month')

plt.figure(figsize=(18, 8))
sns.lineplot(data=year_month_rev, x='year_month', y='revenue', marker='o')
plt.xticks(rotation=45)
plt.grid()
plt.title('Monthly Revenue Trend')
# Out:
# Text(0.5, 1.0, 'Monthly Revenue Trend')

# %%
pivot_rev = year_month_rev.pivot(index='year', columns='month', values='revenue')

plt.figure(figsize=(18, 8))
sns.heatmap(pivot_rev, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title('Revenue Heatmap: Year vs Month')
plt.show()

# %% [markdown]
# - see 2 spikes of monthly revenue in Oct-Nov in years 2010 and 2011; can be due to purchases before New Year; (pre-holiday surge)
# - see 2 huge drop (to norm) of monthly revenue in Dec in years 2010 and 2011; probably due to the peak; (post-peak exhaustion)

# %%
year_product_rev = df_base.groupby(['year', 'stock_code', 'description'])['revenue'].sum().reset_index()
year_product_rev = year_product_rev.sort_values(['year', 'revenue'], ascending=[True, False])

top_10_per_year = year_product_rev.groupby('year').head(10).reset_index()
top_10_per_year = top_10_per_year.drop(columns='index').copy()

g = sns.FacetGrid(top_10_per_year, col="year", col_wrap=3, height=8, aspect=1, sharey=False)

g.map_dataframe(
    sns.barplot, 
    x="revenue", 
    y="description", 
    hue="description",  #
    palette="viridis", 
    legend=False       
)

g.set_titles("{col_name} Top Products")
g.set_axis_labels("Revenue", "")

plt.tight_layout()
plt.show()

# %% [markdown]
# -  top 10 bestsellers per year

# %%
year_country_rev = df_base.groupby(['year', 'country'])['revenue'].sum().reset_index()
year_country_rev.sort_values(by='revenue', ascending=False, inplace=True)
top_5_per_year = year_country_rev.groupby('year').head(5).reset_index()

plt.figure(figsize=(16, 8))

sns.barplot(
    data=top_5_per_year, 
    x='revenue', 
    y='country', 
    hue='year', 
    palette='magma',

)

plt.title('Revenue by Country and Year')
plt.legend(loc='lower right')
plt.xlabel('Total Revenue')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# - top 5 contries by revenue per year
